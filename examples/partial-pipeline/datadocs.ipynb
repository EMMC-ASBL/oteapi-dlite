# %% [markdown]
# ![image.png](attachment:0ee7214b-2346-4580-b3be-c8a0607fcdf1.png)

# %% [markdown]
# ![image.png](attachment:fac8dab8-a504-4e7b-b808-1dded5acf411.png)

# %% [markdown]
# ![image.png](attachment:28546772-1548-41bf-9bbf-0d2fe47f30dc.png)

# %% [markdown]
# ![image.png](attachment:fea27c65-8dba-4a55-ba12-7530d8fe0f7a.png)

# %% [markdown]
# ![image.png](attachment:76f5d208-3697-47a6-a89b-fc16daa40cca.png)
